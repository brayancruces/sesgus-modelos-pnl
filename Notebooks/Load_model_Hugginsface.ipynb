# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install transformers
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 5.3 MB 32.2 MB/s
# ...
#      |████████████████████████████████| 163 kB 68.8 MB/s
# ...
#      |████████████████████████████████| 7.6 MB 32.5 MB/s
# ...

# %%
# !pip install huggingface_hub
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
import torch
from transformers import BertTokenizer,BertForSequenceClassification

# %%
model=torch.load("/content/drive/MyDrive/Hackathones/BBVA Hakathon 2022/BETO model/Bias Classification Beto Model/model")

# %%
from huggingface_hub import notebook_login

# %%
notebook_login()
# Out:
# Login successful
# Your token has been saved to /root/.huggingface/token

# %%
model.push_to_hub('Jhonatan51998/bias_model',use_auth_token='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')
# Out:
# CommitInfo(commit_url='https://huggingface.co/Jhonatan51998/bias_model/commit/715c77088aa475af70913c083f0b6de6a5dc98db', commit_message='Upload BertForSequenceClassification', commit_description='', oid='715c77088aa475af70913c083f0b6de6a5dc98db', pr_url=None, pr_revision=None, pr_num=None)

# %%
model2=torch.load('/content/drive/MyDrive/Hackathones/BBVA Hakathon 2022/BETO model/Toxic Model/toxic_model')
model2.push_to_hub('Jhonatan51998/toxicity_sentiment_model',use_auth_token='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')
# Out:
# CommitInfo(commit_url='https://huggingface.co/Jhonatan51998/toxicity_sentiment_model/commit/6f88fe74e9cc11f3e63f0801a9e0054d99784ea4', commit_message='Upload BertForSequenceClassification', commit_description='', oid='6f88fe74e9cc11f3e63f0801a9e0054d99784ea4', pr_url=None, pr_revision=None, pr_num=None)

# %%
#torch.load('Jhonatan51998/toxicity_sentiment_model')


model = BertForSequenceClassification.from_pretrained('Jhonatan51998/toxicity_sentiment_model',use_auth_token='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')
# Out:
# Downloading:   0%|          | 0.00/683 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/439M [00:00<?, ?B/s]

# %%
model2= BertForSequenceClassification.from_pretrained('Jhonatan51998/bias_model',use_auth_token='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')
# Out:
# Downloading:   0%|          | 0.00/683 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/439M [00:00<?, ?B/s]
